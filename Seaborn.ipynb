# %%
# Seaborn

import seaborn as sns
# seaborn package has its own datasets for study pupose
df=sns.load_dataset('tips')
# to predict tips from the i/p features
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
#
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# correlation-to find the relation between different features(correlation can be retrieved from numerical values)
# Correlation is a statistical measure that describes the strength and direction of a linear relationship between two or more variables. In your code, you're working with the tips dataset loaded using Seaborn.
#  Correlation can help you understand which features in this dataset might be related to the 'tip' amount.
df.corr(numeric_only=True)
# max value-1
# min value- can be negative or zero
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# Feature Selection Methods:
#
# 1.Correlation:
#
# 2.Chi-Square Test:used for extracting relationship of features in object datatype
# The Chi-Square test is used to determine if there is a significant association between two categorical variables. In the context of your code and the 'tips' dataset, you might want to use the Chi-Square test to see if there is a relationship between features like 'sex' and 'smoker' or 'day' and 'time'.
# Interpreting the Results
#
# Chi-Square Statistic: A measure of the difference between observed and expected frequencies.
# P-value: The probability of observing the data if there were no association between the variables. A low p-value (typically less than 0.05) suggests a significant association.
# Degrees of Freedom: The number of independent values in the calculation.
# Expected Frequencies: The frequencies expected if there were no association between the variables.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table (also called a cross-tabulation or crosstab)
# This table shows the frequencies of each combination of categories
contingency_table = pd.crosstab(df['total_bill'], df['tip'])


# Perform the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(contingency_table)
# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:", expected)
# Out:
# tip         1.00   1.01   1.10   1.17   1.25   1.32   1.36   1.44   1.45   \
# total_bill
# 3.07            1      0      0      0      0      0      0      0      0
# 5.75            1      0      0      0      0      0      0      0      0
# 7.25            1      0      0      0      0      0      0      0      0
# 7.51            0      0      0      0      0      0      0      0      0
# 7.56            0      0      0      0      0      0      0      1      0
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 45.35           0      0      0      0      0      0      0      0      0
# 48.17           0      0      0      0      0      0      0      0      0
# 48.27           0      0      0      0      0      0      0      0      0
# 48.33           0      0      0      0      0      0      0      0      0
# 50.81           0      0      0      0      0      0      0      0      0
#
# ...

# %%
# sns.heatmap() creates a heatmap visualization
# where color intensity represents the strength of correlation. annot=True displays the correlation values on the heatmap, and cmap='coolwarm' provides
#  a color scheme for easier interpretation (positive correlations in warm colors, negative correlations in cool colors).
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# joint plot(only for numerical values)
# joint plot:A joint plot is a visualization tool in Seaborn that allows you to study the relationship between two variables. It displays a scatter plot of the two variables along with their individual distributions (histograms or kernel density estimates) on the margins.
#  This provides a comprehensive view of both the joint and marginal distributions of the data.
sns.jointplot(x='tip',y='total_bill',data=df)
# total_bill max lies between 10 and 20
# tip lies between 2 and 3

# %%
sns.jointplot(x='tip',y='size',data=df,hue='sex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')
# distribution is also shown

# Regression Line: A linear regression line will be fitted to the data and plotted on top of the scatter plot.
#  This line shows the overall trend of the relationship between the two variables.

# Distribution Plots: Along the top and right sides of the plot,
# you'll see histograms (or kernel density estimations) showing the
# individual distributions of tip and total_bill, respectively.
# These give you an idea of how each variable is distributed on its own.

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
# Pair Plots
# A pair plot is a powerful visualization tool in Seaborn
# that allows you to see the pairwise relationships between all numerical features in a dataset.
#  It creates a grid of scatter plots where each scatter plot shows the relationship between two different features.
# The diagonal of the grid shows the distribution of each individual feature.
# You can customize the pair plot further with arguments like hue (to color points based on a categorical variable),
#  diag_kind (to change the diagonal plots), kind (to change the type of plot on the off-diagonal), and more.
#  To see the output, run the code. The pair plot will show
# the relationships between all the numerical features in the 'tips' dataset, including 'total_bill', 'tip', and 'size'.
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')
# can include object values

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='time')

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# Understanding Count Plots

# A count plot is a type of categorical plot in Seaborn that shows the counts
#  of observations in each category of a categorical variable using bars.
#  It's essentially a histogram for categorical data.

sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# barplot
sns.barplot(x='total_bill',y='day',data=df,hue='sex')
# line indicates the average value

# A bar plot is a visualization tool in Seaborn that displays the estimated mean of a numerical variable for
# different categories of a categorical variable.
# It represents these means as bars, with the height of each bar corresponding to the mean value.
# Error bars can also be added to show the uncertainty around the estimate.
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# Boxplot
# outliers can be detected using box plot
sns.boxplot(x='smoker',y='total_bill',data=df)


# The Box

#     The central line: Represents the median of the data. This is the middle value when the data is sorted(50%)
#     The lower edge of the box: Represents the first quartile (Q1), which is the 25th percentile of the data.
# This means that 25% of the data values are below this line.
#     The upper edge of the box: Represents the third quartile (Q3), which is the 75th percentile of the data.
# This means that 75% of the data values are below this line.
#     The height of the box: Represents the interquartile range (IQR),
#  which is the difference between Q3 and Q1 (IQR = Q3 - Q1). This range contains the middle 50% of the data.

# The Whiskers

#     The lines extending from the box (whiskers): Typically represent the range of the data within
#  1.5 times the IQR from the edges of the box.
#         Upper whisker: Extends to the highest data point that is within 1.5 * IQR above Q3.
#         Lower whisker: Extends to the lowest data point that is within 1.5 * IQR below Q1.

# Outliers

#     Points plotted individually beyond the whiskers: These are data points that
# fall outside the typical range and are considered outliers. They can indicate unusual or extreme values in the data
# how to calculate Q2:

# data-7,8,1,1,2,4,3,5
# 1.sort in ascending order 1 1 3 4 5 6 7 8
# 2.divide it in to 2 equal parts   1 1 3 4        5 6 7 8
# Q2=median of whole data (5+4)/2=4.5
# Q3=6.5(median of 2nd part)
# Q1=2(median of first part)
# 3.calculate IQR=Q3-Q1=4.5

# # TOP = Q3+1.5*IQR=6.5+1.5*4.5=13.25              values above 13.25 will be detected as outliers
# BOTTOM=Q1-1.5*IQR=-4.75                           values below 4.75
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# sns.boxplot(y='total_bill',data=df)
import matplotlib.pyplot as plt
def removal_box_plot(df,columns,threshold):
  sns.boxplot(df[columns])
  plt.title(f'original box plot of {columns}')
  plt.show()
  removed_outliers=df[df[columns]<=threshold]
  print(removed_outliers)
  sns.boxplot(removed_outliers[columns])
  return removed_outliers

threshold=38
df_without_outliers=removal_box_plot(df,'total_bill',threshold)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [230 rows x 7 columns]

# %%
import numpy as np
Q1=np.percentile(df['total_bill'],25,method='midpoint')
Q3=np.percentile(df['total_bill'],75,method='midpoint')
# The position of Q3 is calculated as: (n + 1) * (75 / 100), where n is the number of data points (7 in this case).

    # Position of Q3 = (7 + 1) * (75 / 100) = 6

IQR=Q3-Q1
print(Q1,Q3,IQR)
upper=Q3+1.5*IQR
upper_outliers=df[df['total_bill']>upper]
# upper_array=np.array(df['total_bill']>=upper)
# print(upper_array.sum())
lower=Q1-1.5*IQR
lower_outliers=df[df['total_bill']<lower]
# lower_array=np.array(df['total_bill']<=lower)
print(upper,lower)
# print(lower_array.sum())
# Out:
# 13.325 24.174999999999997 10.849999999999998
# 40.449999999999996 -2.9499999999999993

# %%
import matplotlib.pyplot as plt
def outlier_removal(df,columns,threshhold):
  sns.boxplot(df[columns])
  plt.title(f'original plot {columns}')
  plt.show()
  removed_outliers=df[df[columns]<=threshhold]
  sns.boxplot(removed_outliers[columns])
  plt.title(f'removed outliers plot{columns}')
  plt.show()
  return removed_outliers

threshhold=40
outlier_removal(df,'total_bill',threshhold)
# df1=outlier_removal(df,'total_bill',38)
# df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [234 rows x 7 columns]

# %%
import numpy as np
Q1,Q2,Q3=np.percentile(df['total_bill'],[25,50,75],method='midpoint')
IQR=Q3-Q1
print(IQR)
df.isna().sum()
# Out:
# 10.849999999999998
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
upper=Q3+1.5*IQR
lower=Q1-1.5*IQR
upper,lower

# for i in df.index:
#   if df.loc[i,'total_bill']<=lower or df.loc[i,'total_bill']>=upper:
#     df.loc[i,'total_bill']=np.NaN
# df.isna().sum()
# df.fillna(df['total_bill'].mean(),inplace=True)
# df.isna().sum()
# TypeError: Cannot setitem on a Categorical with a new category (18.79868085106383), set the categories first
# Out:
# (40.449999999999996, -2.9499999999999993)

# %%
# df['total_bill'] = pd.to_numeric(df['total_bill'], errors='coerce') # Convert to numeric
# for i in df.index:
#        if df.loc[i,'total_bill']<=lower or df.loc[i,'total_bill']>=upper:
#          df.loc[i,'total_bill']=np.nan
# df.fillna(df['total_bill'].mean(),inplace=True)
