# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Student_Performance.csv')
df
# Out:
#     Hours_Studied  Previous_Score  New_Score
# 0               7              91        100
# 1               4              65         82
# 2               8              45         98
# 3               5              36         82
# 4               7              66         99
# ..            ...             ...        ...
# 95              3              30         50
# 96              8              57         86
# 97              6              81         95
# 98              3              36         50
# 99              1              25         30
#
# [100 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Hours_Studied     0
# Previous_Score    0
# New_Score         0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x,y
# Out:
# (    Hours_Studied  Previous_Score
#  0               7              91
#  1               4              65
#  2               8              45
#  3               5              36
#  4               7              66
#  ..            ...             ...
#  95              3              30
#  96              8              57
#  97              6              81
#  98              3              36
#  99              1              25
#
#  [100 rows x 2 columns],
#  0     100
#  1      82
#  2      98
#  3      82
#  4      99
#       ...
#  95     50
#  96     86
#  97     95
#  98     50
#  99     30
#  Name: New_Score, Length: 100, dtype: int64)

# %%
print(list(zip(x,y)))
# Out:
# [('Hours_Studied', 100), ('Previous_Score', 82)]

# %%
import seaborn as sns
sns.regplot(x=df['Hours_Studied'],y=df['New_Score'],color='red')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='New_Score'>

# %%
sns.regplot(x=df['Previous_Score'],y=y,color='b')
# Out:
# <Axes: xlabel='Previous_Score', ylabel='New_Score'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train
# Out:
#     Hours_Studied  Previous_Score
# 11              8              73
# 47              4              54
# 85              9              81
# 28              3              74
# 93              8              76
# ..            ...             ...
# 60              7              70
# 71              7              54
# 14              5              68
# 92              7              60
# 51              2              65
#
# [70 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.svm import SVR

from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,mean_absolute_percentage_error,root_mean_squared_error

lst=[LinearRegression(),DecisionTreeRegressor(),RandomForestRegressor(),SVR(),KNeighborsRegressor()]

for i in lst:

  print(f'model is {i}')

  print()

  i.fit(x_train,y_train)

  y_predict=i.predict(x_test)

  r2=r2_score(y_test,y_predict)

  print(f'{i} has R2score {r2}')

  print()

  mape=mean_absolute_percentage_error(y_test,y_predict)

  print(f'{i} has MAPE {mape}')

  print()
# Out:
# model is LinearRegression()
#
# LinearRegression() has R2score 0.9099673716006509
#
# LinearRegression() has MAPE 0.07996883270764468
#
# model is DecisionTreeRegressor()
#
# DecisionTreeRegressor() has R2score 0.8988951183466655
#
# DecisionTreeRegressor() has MAPE 0.06951840047501755
#
# model is RandomForestRegressor()
#
# RandomForestRegressor() has R2score 0.9556118193513718
#
# RandomForestRegressor() has MAPE 0.04440924122960775
#
# model is SVR()
#
# SVR() has R2score 0.3118112407993068
#
# SVR() has MAPE 0.24378443854805026
#
# model is KNeighborsRegressor()
#
# KNeighborsRegressor() has R2score 0.917020494655438
#
# KNeighborsRegressor() has MAPE 0.06808348837954875

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#     Actual   Predicted  Difference
# 83      83   79.332240    3.667760
# 53      86   79.307771    6.692229
# 70      99  105.021921   -6.021921
# 45      76   67.047999    8.952001
# 44      99   98.879800    0.120200
# 39      99   99.415930   -0.415930
# 22     100  104.461322   -4.461322
# 80      60   62.002607   -2.002607
# 10     100  106.167588   -6.167588
# 0      100  105.631458   -5.631458
# 18      40   49.133297   -9.133297
# 30      61   58.639013    2.360987
# 73      90   88.228418    1.771582
# 33     100   89.885746   10.114254
# 90      25   39.627582  -14.627582
# 4       99   91.616482    7.383518
# 76      99   93.273810    5.726190
# 77      54   56.396616   -2.396616
# 12      47   51.911824   -4.911824
# 31      83   74.798509    8.201491
# 55      99  101.171135   -2.171135
# 88      92   91.592012    0.407988
# 26      79   78.235511    0.764489
# 42      73   73.750719   -0.750719
# 69      68   62.051545    5.948455
# 15      52   56.421085   -4.421085
# ...

# %%
print(lr.coef_)
print("slope of TV is ",lr.coef_[0])
print("slope of Radio is ",lr.coef_[1])
print("slope of Newspaper is ",lr.coef_[2])

# or
print(list(zip(x,lr.coef_)))

# %%
print(lr.intercept_)

# %%
r2
