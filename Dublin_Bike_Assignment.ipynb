# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_excel("/content/biking_dataset (1).xlsx")
df
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 0           Berlin             Rainy       53.0   Standard
# 1    San Francisco            Cloudy       39.0   Standard
# 2           Berlin             Sunny       43.0   Electric
# 3    San Francisco            Cloudy       24.0   Standard
# 4         New York             Sunny       24.0   Mountain
# ..             ...               ...        ...        ...
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 0                   62.0                   2.25               High
# 1                    5.0                  21.67             Medium
# ...

# %%
df.head()
# Out:
#             City Weather Condition  Rider Age Bike Model  Ride Duration (min)  \
# 0         Berlin             Rainy       53.0   Standard                 62.0
# 1  San Francisco            Cloudy       39.0   Standard                  5.0
# 2         Berlin             Sunny       43.0   Electric                106.0
# 3  San Francisco            Cloudy       24.0   Standard                119.0
# 4       New York             Sunny       24.0   Mountain                 11.0
#
#    Distance Covered (km) Rider Satisfaction  Bike Rental Cost ($)
# 0                   2.25               High                 22.63
# 1                  21.67             Medium                  7.87
# 2                  28.40               High                 39.40
# 3                   5.66                Low                 37.63
# 4                  25.74                Low                 13.12

# %%
df.tail()
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 895                 55.0                  28.35             Medium
# 896                 14.0                  11.99               High
# 897                 23.0                   2.78               High
# 898                110.0                   2.27               High
# 899                 17.0                   9.70             Medium
#
#      Bike Rental Cost ($)
# 895                 26.30
# 896                 13.78
# 897                 20.47
# 898                 39.62
# 899                 13.02

# %%
df.sample(5)
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 300        Chicago             Snowy       45.0   Mountain
# 426         London             Snowy       43.0   Mountain
# 32          London             Snowy       36.0   Mountain
# 472        Chicago            Cloudy       55.0   Standard
# 129  San Francisco             Sunny       32.0   Standard
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 300                115.0                  13.81                Low
# 426                 37.0                  22.33                Low
# 32                  22.0                  16.49               High
# 472                110.0                  21.70               High
# 129                102.0                   3.91               High
#
#      Bike Rental Cost ($)
# 300                 36.63
# 426                 16.78
# 32                  12.59
# 472                 36.28
# 129                 33.64

# %%
df.shape
# Out:
# (900, 8)

# %%
df.dtypes
# Out:
# City                      object
# Weather Condition         object
# Rider Age                float64
# Bike Model                object
# Ride Duration (min)      float64
# Distance Covered (km)    float64
# Rider Satisfaction        object
# Bike Rental Cost ($)     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   890 non-null    object
#  1   Weather Condition      889 non-null    object
#  2   Rider Age              885 non-null    float64
#  3   Bike Model             890 non-null    object
#  4   Ride Duration (min)    887 non-null    float64
#  5   Distance Covered (km)  887 non-null    float64
#  6   Rider Satisfaction     889 non-null    object
#  7   Bike Rental Cost ($)   891 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 56.4+ KB

# %%
# Checking no. of missing values

df.isna().sum()
# Out:
# City                     10
# Weather Condition        11
# Rider Age                15
# Bike Model               10
# Ride Duration (min)      13
# Distance Covered (km)    13
# Rider Satisfaction       11
# Bike Rental Cost ($)      9
# dtype: int64

# %%
# Checking unique values

print("Unique values in each column\n\n")
for i in df.columns:
  print(i, ":       \n", df[i].unique(),"\n\n")
# Out:
# Unique values in each column
#
#
# City :
#  ['Berlin' 'San Francisco' 'New York' 'London' 'Chicago' 'Dublin' nan]
#
#
# Weather Condition :
#  ['Rainy' 'Cloudy' 'Sunny' 'Snowy' nan]
#
#
# Rider Age :
#  [53. 39. 43. 24. 25. 41. 57. 26. 20. 38. 48. 21. 37. 33. 27. 60. 22. 28.
#  46. 32. 23. 51. 19. 36. 31. 49. 54. 40. 44. 59. 45. 34. 56. 35. 30. 18.
#  47. nan 55. 42. 52. 50. 58. 29.]
#
#
# Bike Model :
#  ['Standard' 'Electric' 'Mountain' nan 'Manual']
#
#
# Ride Duration (min) :
#  [ 62.   5. 106. 119.  11.  92.  73.  89.  96.  22.  36.  49.  37.  78.
#   77.  53. 101.  75.  72.  32.  91. 100.  48.  84. 114.  59.  14. 107.
#   40.  38.  20. 109.  41.  29.  12.  88. 116.  98.  52. 104.  74.  71.
#  108.  60.  27.  10.  30.  19.  16.   9.  90.  31.  83.  39.  17.  94.
#    7.  33.  nan  68. 117.  15.  42.  85.  50. 102.  58.  97.  81.  79.
#   99.  56. 110.  76.  18. 115.   6.  65. 112.  21.  82.  93.  95.  45.
#   46.  80.  57. 113.  35.  66.  34.  70. 103.  23.  54.  43.  67.  63.
# ...

# %%
# Filling Missing Values

for i in ["City", "Weather Condition", "Rider Age", "Bike Model", "Ride Duration (min)", "Rider Satisfaction"]:
  df[i].fillna(df[i].mode()[0], inplace=True)
for i in ["Distance Covered (km)", "Bike Rental Cost ($)"]:
  df[i].fillna(df[i].mean(), inplace=True)

df.isna().sum()
# Out:
# City                     0
# Weather Condition        0
# Rider Age                0
# Bike Model               0
# Ride Duration (min)      0
# Distance Covered (km)    0
# Rider Satisfaction       0
# Bike Rental Cost ($)     0
# dtype: int64

# %%
df.duplicated().sum() # no duplicate values
# Out:
# 0

# %%
df
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 0           Berlin             Rainy       53.0   Standard
# 1    San Francisco            Cloudy       39.0   Standard
# 2           Berlin             Sunny       43.0   Electric
# 3    San Francisco            Cloudy       24.0   Standard
# 4         New York             Sunny       24.0   Mountain
# ..             ...               ...        ...        ...
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 0                   62.0                   2.25               High
# 1                    5.0                  21.67             Medium
# ...

# %%
#Descriptive Analysis

# %%
# Outlier Detection

plt.figure()
sns.boxplot(df)
plt.xticks(rotation=45)
plt.show()

# No outliers found

# %%
# Histogram of rental costs

plt.hist(df["Bike Rental Cost ($)"], bins=15, edgecolor="black")
plt.title("Distribution of Bike Rental Costs")
plt.xlabel("Cost ($)")
plt.ylabel("Frequency")
plt.show()

'''
rentals frequency start dipping sharply above $40.
Can provide promotions above $40 to encourage riders ride more
thereby attract the larger distance riders
and improve the high bracket rental revenue
'''
# Out:
# '\nrentals frequency start dipping sharply above $40.\nCan provide promotions above $40 to encourage riders ride more\nthereby attract the larger distance riders\nand improve the high bracket rental revenue\n'

# %%
# Plot across rider satisfaction for each weather condition
sns.countplot(x="Weather Condition", hue="Rider Satisfaction", data=df)
plt.title("Rider Satisfaction by Weather Condition")
plt.xlabel("Weather Condition")
plt.ylabel("Count")
plt.legend(title="Satisfaction Level")
plt.show()

'''
Rider Satisfaction is less in snowy weather but high in others, especially rainy weather condition
so to increase the rider satisfaction in snowy weather,
bike conditions can be checked and made favourable
if needed, prices can be reduced.
'''
# Out:
# '\nRider Satisfaction is less in snowy weather but high in others, especially rainy weather condition\nso to increase the rider satisfaction in snowy weather,\nbike conditions can be checked and made favourable\nif needed, prices can be reduced.\n'

# %%
# Plot for city count across weather conditions

sns.countplot(x="City", hue="Weather Condition", data=df)
plt.title("City Count across weather conditions")
plt.xlabel("City")
plt.ylabel("Count")
plt.legend(title="Weather Condition")
plt.show()

'''
In every city, rider usage is more for the rainy weather condition
In the previous plot, we have already seen that rider satisfaction is more
for the rainy weather condition
'''
# Out:
# '\nIn every city, rider usage is more for the rainy weather condition\nIn the previous plot, we have already seen that rider satisfaction is more\nfor the rainy weather condition\n'

# %%
# Checking correlation

sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
df.drop('Distance Covered (km)', axis=1, inplace=True)
df
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 0           Berlin             Rainy       53.0   Standard
# 1    San Francisco            Cloudy       39.0   Standard
# 2           Berlin             Sunny       43.0   Electric
# 3    San Francisco            Cloudy       24.0   Standard
# 4         New York             Sunny       24.0   Mountain
# ..             ...               ...        ...        ...
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min) Rider Satisfaction  Bike Rental Cost ($)
# 0                   62.0               High                 22.63
# 1                    5.0             Medium                  7.87
# ...

# %%
df["Weather Condition"].unique()
# Out:
# array(['Rainy', 'Cloudy', 'Sunny', 'Snowy'], dtype=object)

# %%
df["Bike Model"].value_counts()
# Out:
# Bike Model
# Mountain    308
# Standard    297
# Electric    294
# Manual        1
# Name: count, dtype: int64

# %%
# Encoding

from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
for i in ["City", "Weather Condition", "Bike Model", "Rider Satisfaction"]:
  df[i] = lab.fit_transform(df[i])
df
# Out:
#      City  Weather Condition  Rider Age  Bike Model  Ride Duration (min)  \
# 0       0                  1       53.0           3                 62.0
# 1       5                  0       39.0           3                  5.0
# 2       0                  3       43.0           0                106.0
# 3       5                  0       24.0           3                119.0
# 4       4                  3       24.0           2                 11.0
# ..    ...                ...        ...         ...                  ...
# 895     4                  1       55.0           0                 55.0
# 896     3                  0       47.0           2                 14.0
# 897     5                  3       49.0           2                 23.0
# 898     1                  3       19.0           2                110.0
# 899     2                  1       37.0           3                 17.0
#
#      Rider Satisfaction  Bike Rental Cost ($)
# ...

# %%
# Confidence Intervals for two samples

sample1 = df['Bike Rental Cost ($)'].sample(n=50, random_state=42)
sample2 = df['Bike Rental Cost ($)'].sample(n=50, random_state=0)

import scipy.stats as stats

# we are taking 95% confidence level

CI_1 = stats.t.interval(0.95, len(sample1) - 1, loc=np.mean(sample1), scale=stats.sem(sample1))
CI_2 = stats.t.interval(0.95, len(sample2) - 1, loc=np.mean(sample2), scale=stats.sem(sample2))

print(f"Confidence interval for 1st sample is {CI_1}")
print(f"Confidence interval for 2nd sample is {CI_2}")
# Out:
# Confidence interval for 1st sample is (24.346444764965288, 29.954355235034715)
# Confidence interval for 2nd sample is (26.158336232436064, 31.492063767563927)

# %%
# ANOVA

independents = ["City", "Weather Condition", "Bike Model", "Rider Satisfaction"]

for i in independents:
  print(f"{i} vs Bike Rental Cost")
  print()
  independent_groups = df['Bike Rental Cost ($)'].groupby(df[i])
  f_value, p_value = stats.f_oneway(*[group for name, group in independent_groups])
  print("F-value:", f_value)
  print("P-value:", p_value)

  # critical value

  alpha = 0.05
  dfn = len(df[i].unique()) - 1 # no. of categories - 1
  dfd = len(df) - len(df[i].unique()) # no. of samples - no. of categories
  critical_value = stats.f.ppf(1 - alpha, dfn, dfd)
  print("critical value:",critical_value)
  print()


'''
as per the anova results comparing f value with critical value
we can reject the null hypothesis for Bike Model (since f value>critical value)
but not for the other three, i.e. City and Weather Condition and Rider Satisfaction
'''
# Out:
# City vs Bike Rental Cost
#
# F-value: 0.4450135199581932
# P-value: 0.8170675047753619
# critical value: 2.2241164378248914
#
# Weather Condition vs Bike Rental Cost
#
# F-value: 1.3936770644825172
# P-value: 0.24331510105431128
# critical value: 2.6148383408407883
#
# Bike Model vs Bike Rental Cost
#
# F-value: 51.458459478481615
# P-value: 1.087656849833858e-30
# critical value: 2.6148383408407883
#
# Rider Satisfaction vs Bike Rental Cost
#
# F-value: 0.05452209457230593
# P-value: 0.9469407243486214
# critical value: 3.00575950503344
# '\nas per the anova results comparing f value with critical value\nwe can reject the null hypothesis for Bike Model (since f value>critical value)\nbut not for the other three, i.e. City and Weather Condition and Rider Satisfaction\n'

# %%
df["Bike Model"].value_counts()
# Out:
# Bike Model
# 2    308
# 3    297
# 0    294
# 1      1
# Name: count, dtype: int64

# %%
# Boxplots for each Bike Model

sns.boxplot(x='Bike Model', y='Bike Rental Cost ($)', data=df)
plt.title('Bike Rental Cost by Bike Model')
plt.xlabel('City')
plt.ylabel('Bike Rental Cost')

'''
we can see the variance between groups occured as high
as we got f value greater than critical value
because we have only one bike in the category of bike1 (Manual)
around the range 40
'''
# Out:
# '\nwe can see the variance between groups occured as high\nas we got f value greater than critical value\nbecause we have only one bike in the category of bike1 (Manual)\naround the range 40\n'

# %%
df["Weather Condition"].unique()
# Out:
# array([1, 0, 3, 2])

# %%
# t-test

'''
though t tests are implemented when you have 2 categories within a feature,
let's take two categories from the weather condition and find out the t-statistic and
p-value to see if there is a significant difference between them.
'''

weather0 = df[df['Weather Condition'] == 0]['Bike Rental Cost ($)']
weather1 = df[df['Weather Condition'] == 1]['Bike Rental Cost ($)']
t_statistic, p_value = stats.ttest_ind(weather0, weather1)
print("t-statistic:", t_statistic)
print("P-value:", p_value)

'''
since p value> 0.05, we can't reject the null hypothesis
which means that there is no significant difference between the two categories
'''
# Out:
# t-statistic: 1.0632651063001617
# P-value: 0.2882195912085243
# "\nsince p value> 0.05, we can't reject the null hypothesis\nwhich means that there is no significant difference between the two categories\n"

# %%
# splitting the dataframe to input and output features
x = df.drop('Bike Rental Cost ($)', axis=1)
y = df['Bike Rental Cost ($)']

# %%
# splitting the training and testing data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Normalisation

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (630, 6)

# %%
# Principal Component Analysis

from sklearn.decomposition import PCA
pca = PCA(0.88)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)

# %%
x_train.shape # features reduced to 5 by PCA
# Out:
# (630, 5)

# %%
# Model Creation and Performance Evaluation using R2_Score and MAPE

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_absolute_percentage_error

linear = LinearRegression()
tree = DecisionTreeRegressor()
forest = RandomForestRegressor()
sv = SVR()
knn = KNeighborsRegressor()

lst=[linear,tree,forest,sv,knn]

for i in lst:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  r2=r2_score(y_test,y_pred)
  mape=mean_absolute_percentage_error(y_test,y_pred)
  print(f'{i}: \nR2score: {r2} \nMAPE: {mape} \n\n')
  print()
# Out:
# LinearRegression():
# R2score: 0.7670244571793514
# MAPE: 0.1835773733444684
#
#
#
# DecisionTreeRegressor():
# R2score: 0.5659209406243011
# MAPE: 0.22752170486059167
#
#
#
# RandomForestRegressor():
# R2score: 0.7809898383952077
# MAPE: 0.1759643236899305
#
#
#
# SVR():
# R2score: 0.7180186909794835
# MAPE: 0.21162863452338793
#
#
#
# KNeighborsRegressor():
# R2score: 0.6389133548531972
# MAPE: 0.2310715208847296

# %%
# Hyperparameter Tuning

from sklearn.model_selection import GridSearchCV
cls1 = RandomForestRegressor()
param1 = {'n_estimators': [50, 100, 200], 'criterion' : ['squared_error', 'absolute_error'], 'max_depth': [None, 10, 20]}
gv = GridSearchCV(cls1, param1, cv=5, scoring="accuracy")
gv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
print(gv.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_depth': None, 'n_estimators': 50}

# %%
cls2 = RandomForestRegressor(n_estimators=50)
cls2.fit(x_train, y_train)
y_pred1 =cls2.predict(x_test)
r2=r2_score(y_test,y_pred1)
mape=mean_absolute_percentage_error(y_test,y_pred1)
print(f'R2score: {r2} \nMAPE: {mape}')
# Out:
# R2score: 0.7770257431208116
# MAPE: 0.1755881093658953
